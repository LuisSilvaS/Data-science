# %% [markdown]
# <a href="https://colab.research.google.com/github/M20170138952/Data-science/blob/main/%C3%81rvores_de_decis%C3%A3o_e_florestas_aleat%C3%B3rias_em_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Árvores de decisão e florestas aleatórias em Python

# %% [markdown]
# Este é o código para o vídeo da conferência que aborda sobre os métodos de árvores de decisões em Python. Consulte o vídeo para uma explicação completa.
#
# ## Importando bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Obtendo os dados

# %%
df = pd.read_csv('/kyphosis.csv')

# %%
df.head(100)
# Out:
#    Kyphosis  Age  Number  Start
# 0    absent   71       3      5
# 1    absent  158       3     14
# 2   present  128       4      5
# 3    absent    2       5      1
# 4    absent    1       4     15
# ..      ...  ...     ...    ...
# 76  present  157       3     13
# 77   absent   26       7     13
# 78   absent  120       2     13
# 79  present   42       7      6
# 80   absent   36       4     13
#
# [81 rows x 4 columns]

# %% [markdown]
# ## EDA
#
# Vamos observar um simples pairplot para este pequeno conjunto de dados.

# %%
sns.pairplot(df,hue='Kyphosis',palette='Set1')

# %% [markdown]
# ## Divisão treino-teste
#
# Vamos dividir os dados em um conjunto de treinamento e um conjunto de testes!

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Kyphosis',axis=1)
y = df['Kyphosis']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %% [markdown]
# ## Árvores de decisão
#
# Começaremos apenas treinando uma única árvore de decisão.

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Previsão e Avaliação
#
# Vamos avaliar a nossa árvore de decisão.

# %%
predictions = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#       absent       1.00      0.76      0.86        21
#      present       0.44      1.00      0.62         4
#
#     accuracy                           0.80        25
#    macro avg       0.72      0.88      0.74        25
# weighted avg       0.91      0.80      0.82        25

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[16  5]
#  [ 0  4]]

# %% [markdown]
# ## Visualização de árvore
#
# O Scikit learn possui alguns recursos de visualização incorporados para árvores de decisão. Você não usará isso com freqüência e requer que você instale a biblioteca pydot, mas aqui está um exemplo do código para executar isso:

# %%
from io import StringIO
from IPython.display import Image  
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
import pydot 

features = list(df.columns[1:])
features
# Out:
# ['Age', 'Number', 'Start']

# %%
dot_data = StringIO()  
export_graphviz(dtree, out_file=dot_data,feature_names=features,filled=True,rounded=True)

graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph[0].create_png())

# %% [markdown]
# ## Florestas aleatórias
#
# Agora vamos comparar o modelo da árvore de decisão com uma floresta aleatória.

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-27-1f0df70d2245> in <module>()
# ----> 1 from sklearn.ensemble import RandomForestClassifier
#       2 rfc = RandomForestClassifier(n_estimators=100)
#       3 rfc.fit(X_train, y_train)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/__init__.py in <module>()
#       5
#       6 from .base import BaseEnsemble
# ----> 7 from .forest import RandomForestClassifier
#       8 from .forest import RandomForestRegressor
#       9 from .forest import RandomTreesEmbedding
#
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/forest.py in <module>()
#      61 from ..exceptions import DataConversionWarning, NotFittedError
#      62 from .base import BaseEnsemble, _partition_estimators
# ---> 63 from ..utils.fixes import parallel_helper, _joblib_parallel_args
#      64 from ..utils.multiclass import check_classification_targets
#      65 from ..utils.validation import check_is_fitted
#
# ImportError: cannot import name 'parallel_helper' from 'sklearn.utils.fixes' (/usr/local/lib/python3.7/dist-packages/sklearn/utils/fixes.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(confusion_matrix(y_test,rfc_pred))
# Out:
# [[18  2]
#  [ 3  2]]

# %%
print(classification_report(y_test,rfc_pred))
# Out:
#              precision    recall  f1-score   support
#
#      absent       0.86      0.90      0.88        20
#     present       0.50      0.40      0.44         5
#
# avg / total       0.79      0.80      0.79        25
