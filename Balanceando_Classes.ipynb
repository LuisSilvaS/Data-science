# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisSilvaS/Notebooks_Data-science/blob/main/Balanceando_Classes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# !python --version
# Out:
# Python 3.8.16

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ds = pd.read_csv("/faces.csv")
df = ds.drop(columns=['Unnamed: 0'])

# %%
df
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.829912  1.061662  1.185001  2.258663  3.001352  1.552293  1.410400
# 1      0.474894  1.150886  1.274177  2.440088  2.467688  2.034386  1.213321
# 2      0.552209  0.851182  1.341329  2.149595  2.700470  1.540714  0.873655
# 3      0.550864  1.722460  0.966495  1.460703  1.889776  1.776710  1.671614
# 4      0.233800  1.977882  1.377205  1.204984  2.230107  1.856627  1.761129
# ...         ...       ...       ...       ...       ...       ...       ...
# 11995  1.154870  2.860876  0.450821 -0.262768  1.302428  1.545433  0.774128
# 11996  1.145323  2.748007  0.117930  0.724799  1.448204  2.253423  1.367286
# 11997  0.089946  0.830327  1.070200  0.983064  2.347783  2.646693  2.437767
# 11998  1.191038  1.950142  1.059780  0.347186  2.710961  2.735057  0.975503
# 11999  0.850712  1.973563  0.861236 -0.005988  2.439733  2.333976  0.466719
#
# ...

# %%
X = df.drop('target', axis=1) 
y = df['target']

# %%
#!pip install imblearn

# %%
from imblearn.under_sampling import RandomUnderSampler  

under_sampler = RandomUnderSampler()
X_res, y_res = under_sampler.fit_resample(X, y)

# %%
df = pd.DataFrame(X_res)
df = df.assign(target = y_res)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2996 entries, 0 to 2995
# Columns: 129 entries, 0 to target
# dtypes: float64(128), object(1)
# memory usage: 2.9+ MB

# %%
df
# Out:
#              0         1         2         3         4         5         6  \
# 0     2.004334  3.879037  2.040535  0.433677  3.442449  2.870431  1.735796
# 1     0.552209  0.851182  1.341329  2.149595  2.700470  1.540714  0.873655
# 2    -1.037848  1.028804  2.195733  1.863171  2.713289  3.484635  4.323343
# 3     0.932119  0.946576  0.356049  1.127565  1.587442  0.683708  0.826390
# 4     0.333353  1.743069  1.193162  1.863042  1.309210  2.972258  0.783601
# ...        ...       ...       ...       ...       ...       ...       ...
# 2991  2.467662  3.797444  0.381344  0.076063  1.206249  1.720125  4.165783
# 2992 -0.064376  1.833733  2.257980  1.697094  1.819436  2.703961  1.585498
# 2993  1.020689  1.381628  0.193139  1.503277  2.680217  1.840433  2.148216
# 2994  1.154870  2.860876  0.450821 -0.262768  1.302428  1.545433  0.774128
# 2995  0.089946  0.830327  1.070200  0.983064  2.347783  2.646693  2.437767
#
# ...

# %%
df.to_csv('faces_val.csv')
